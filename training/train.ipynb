# %%
from mingpt.model import GPT
from dataloader import JSONLDataset
import torch

# %%
dataset = JSONLDataset(
    '/nobackup/autodelete/usr/mward19/pile_data_head.jsonl',
    test_size=1,
    window_size=16
)
# Out:
# Length of lines: 9
# Loading dataset:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
model_config = GPT.get_default_config()
model_config.model_type = 'gpt-nano'
model_config.vocab_size = dataset.get_vocab_size()
model_config.block_size = dataset.get_block_size()
model = GPT(model_config)
# Out:
# number of parameters: 2.50M

# %%
# create a Trainer object
from mingpt.trainer import Trainer

train_config = Trainer.get_default_config()
train_config.learning_rate = 5e-4
train_config.max_iters = 20
train_config.num_workers = 0
train_config.device = 'cpu'
trainer = Trainer(train_config, model, dataset)
# Out:
# running on device cpu

# %%
def batch_end_callback(trainer):
    if trainer.iter_num % 1 == 0:
        print(f"iter_dt {trainer.iter_dt * 1000:.2f}ms; iter {trainer.iter_num}: train loss {trainer.loss.item():.5f}")
trainer.set_callback('on_batch_end', batch_end_callback)

trainer.run()
# Out:
# iter_dt 0.00ms; iter 0: train loss 10.83738
# iter_dt 1261.56ms; iter 1: train loss 10.78425
# iter_dt 1005.78ms; iter 2: train loss 10.71976
# iter_dt 1015.19ms; iter 3: train loss 10.67242
# iter_dt 988.75ms; iter 4: train loss 10.67311
# iter_dt 1014.49ms; iter 5: train loss 10.59376
# iter_dt 990.66ms; iter 6: train loss 10.62060
# iter_dt 971.78ms; iter 7: train loss 10.54892
# iter_dt 982.40ms; iter 8: train loss 10.54913
# iter_dt 989.48ms; iter 9: train loss 10.49092
# iter_dt 976.18ms; iter 10: train loss 10.45267
# iter_dt 957.63ms; iter 11: train loss 10.43875
# iter_dt 995.49ms; iter 12: train loss 10.41056
# iter_dt 982.08ms; iter 13: train loss 10.41290
# iter_dt 996.97ms; iter 14: train loss 10.32757
# iter_dt 1071.97ms; iter 15: train loss 10.29105
# iter_dt 1013.61ms; iter 16: train loss 10.28546
# iter_dt 971.74ms; iter 17: train loss 10.22638
# iter_dt 978.58ms; iter 18: train loss 10.16181
# iter_dt 973.66ms; iter 19: train loss 10.16220
